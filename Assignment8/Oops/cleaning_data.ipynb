# %%
import pandas as pd
import numpy as np 
import matplotlib as mpl
import matplotlib.pyplot as plt
import plotly.graph_objs as go
import plotly.express as px

df1 = pd.read_csv('DegreeConferrals-Table 1.csv')
df2 = pd.read_csv('Person-Table 1.csv')
df3 = pd.read_csv('PersonDemographics-Table 1.csv')

df3.head()
# Out:
#    PersonID              RecordID  YrCde Semester DivCde   Gender  Age  \
# 0  83440210  2019SpringUG83440210   2019   Spring     UG  Male      19
# 1  87244010  2020SpringUG87244010   2020   Spring     UG  Male      54
# 2  93999080  2020SpringUG93999080   2020   Spring     UG  Male      18
# 3  64382640  2018SpringUG64382640   2018   Spring     UG  Female    21
# 4  70994070    2017FallUG70994070   2017     Fall     UG  Female    41
#
#                    Ethnicity FirstGeneration MaritalStatus  \
# 0  Black or African American                             S
# 1                      White                             M
# 2                      White               Y             S
# 3                      White                             S
# 4                      White               Y             M
#
#                                   CitizenshipCountry  \
# 0   United States Of America                     ...
# 1   United States Of America                     ...
# ...

# %%
px.scatter(df2, x='YrInSchool', y='HrsErld', title='Hours Enrolled By Class of Student')

# %%
px.box(df3, x='Age', y='Semester', title='Semester')
